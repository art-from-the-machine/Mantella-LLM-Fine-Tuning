# %% [markdown]
# # Import & Setup

# %%
import pandas as pd
import numpy as np
import json
pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth', None)

# %% [markdown]
# # Data

# %% [markdown]
# `LazyVoiceFinder_export.csv` contains a full export of all Skyrim + DLC dialogue exchanges.
# To generate this dataset:
# 1. Download [Lazy Voice Finder](https://www.nexusmods.com/skyrimspecialedition/mods/8619)
# 2. Set the game to Skyrim in LazyVoiceFinder.exe
# 3. Right-click any column -> Unhide Columns -> (All Columns)
# 4. Go to File -> Export CSV File...

# %%
df_all = pd.read_csv('LazyVoiceFinder_export.csv', low_memory=False)
df_all = df_all.loc[~(df_all['State'].isin(['Bad File Name, No Dialogue','No Voice File']))]
df_all = df_all.loc[(df_all['Dialogue 1 - English'].notna()) & (df_all['Dialogue 1 - English']!='')]
print(df_all.shape)
df_all.head()
# Out:
# (74642, 31)
#    State  Index      Plugin Last Modifier    FormId FormId without Load#  \
# 26   NaN      0  skyrim.esm    skyrim.esm  000130DA             000130DA
# 27   NaN      0  skyrim.esm    skyrim.esm  000130DA             000130DA
# 28   NaN      0  skyrim.esm    skyrim.esm  00013113             00013113
# 29   NaN      0  skyrim.esm    skyrim.esm  00013114             00013114
# 30   NaN      0  skyrim.esm    skyrim.esm  00013115             00013115
#
#     Response Num        Edid Topic FormId                        Topic Edid  \
# 26           1.0  [000130DA]     00035E10  MG07TolfdirForcegreetBranchTopic
# 27           2.0  [000130DA]     00035E10  MG07TolfdirForcegreetBranchTopic
# 28           1.0  [00013113]     0001310D                        [0001310D]
# 29           1.0  [00013114]     0001310C                        [0001310C]
# 30           1.0  [00013115]     0001310A                        [0001310A]
#
#    Topic Text Quest FormId Quest Edid           Quest Name Category/Subtype  \
# 26        NaN     0001F257       MG07  The Staff of Magnus     Topic/Custom
# 27        NaN     0001F257       MG07  The Staff of Magnus     Topic/Custom
# 28        NaN     00036192      MQ203        Alduin's Wall      Scene/Scene
# 29        NaN     00036192      MQ203        Alduin's Wall      Scene/Scene
# 30        NaN     00036192      MQ203        Alduin's Wall      Scene/Scene
#
#      Emotion  \
# 26   Neutral
# 27   Neutral
# 28  Surprise
# 29     Happy
# 30  Surprise
#
#                                                                                        Conditions  \
# 26  GetStage: "The Staff of Magnus" [QUST:0001F257] >= 50\nGetIsID: "Tolfdir" [NPC_:0001C19E] = 1
# 27  GetStage: "The Staff of Magnus" [QUST:0001F257] >= 50\nGetIsID: "Tolfdir" [NPC_:0001C19E] = 1
# 28                                                                                            NaN
# 29                                                                                            NaN
# 30                                                                                            NaN
#
#                    Bsa Name  \
# 26  Skyrim - Voices_en0.bsa
# 27  Skyrim - Voices_en0.bsa
# 28  Skyrim - Voices_en0.bsa
# 29  Skyrim - Voices_en0.bsa
# 30  Skyrim - Voices_en0.bsa
#
#                                                                                                                                                              Full Path  \
# 26  C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa\sound\voice\skyrim.esm\maleoldkindly\mg07_mg07tolfdirforcegreet_000130da_1.fuz
# 27  C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa\sound\voice\skyrim.esm\maleoldkindly\mg07_mg07tolfdirforcegreet_000130da_2.fuz
# 28               C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa\sound\voice\skyrim.esm\femaleuniquedelphine\mq203__00013113_1.fuz
# 29               C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa\sound\voice\skyrim.esm\femaleuniquedelphine\mq203__00013114_1.fuz
# 30                   C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa\sound\voice\skyrim.esm\maleuniqueesbern\mq203__00013115_1.fuz
#
#                                                                               Base Path  \
# 26  C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa
# 27  C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa
# 28  C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa
# 29  C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa
# 30  C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa
#
#                                                                               Path  \
# 26  sound\voice\skyrim.esm\maleoldkindly\mg07_mg07tolfdirforcegreet_000130da_1.fuz
# 27  sound\voice\skyrim.esm\maleoldkindly\mg07_mg07tolfdirforcegreet_000130da_2.fuz
# 28               sound\voice\skyrim.esm\femaleuniquedelphine\mq203__00013113_1.fuz
# 29               sound\voice\skyrim.esm\femaleuniquedelphine\mq203__00013114_1.fuz
# 30                   sound\voice\skyrim.esm\maleuniqueesbern\mq203__00013115_1.fuz
#
#                                     File Name Extensions  \
# 26  mg07_mg07tolfdirforcegreet_000130da_1.fuz       .fuz
# 27  mg07_mg07tolfdirforcegreet_000130da_2.fuz       .fuz
# 28                      mq203__00013113_1.fuz       .fuz
# 29                      mq203__00013114_1.fuz       .fuz
# 30                      mq203__00013115_1.fuz       .fuz
#
#               Voice Type Prompt  \
# 26         maleoldkindly    NaN
# 27         maleoldkindly    NaN
# 28  femaleuniquedelphine    NaN
# 29  femaleuniquedelphine    NaN
# 30      maleuniqueesbern    NaN
#
#                                             Dialogue 1 - English  \
# 26                              You survived! You have it, then?
# 27  Let's hope it's as powerful as the Psijics believe it to be.
# 28                    That's done it! Look, it's coming to life!
# 29                             You did it. There's the entrance!
# 30                 There's no telling what we might find inside!
#
#                                             Dialogue 2 - English  \
# 26                              You survived! You have it, then?
# 27  Let's hope it's as powerful as the Psijics believe it to be.
# 28                    That's done it! Look, it's coming to life!
# 29                             You did it. There's the entrance!
# 30                 There's no telling what we might find inside!
#
#                                            Script Notes Edits  Keyword  \
# 26                                                  NaN   NaN      NaN
# 27                                                  NaN   NaN      NaN
# 28  awe breaking through Delphine's usual jaded persona   NaN      NaN
# 29                                                  NaN   NaN      NaN
# 30                                            excitedly   NaN      NaN
#
#     StringId
# 26   25001.0
# 27   17544.0
# 28   60023.0
# 29   49515.0
# 30   30760.0

# %%
df_all.describe(include='all')
# Out:
#        State         Index      Plugin Last Modifier    FormId  \
# count      0  74642.000000       74642         74642     74642
# unique     0           NaN           4             5     35455
# top      NaN           NaN  skyrim.esm    skyrim.esm  0001FB79
# freq     NaN           NaN       61165         59802        56
# mean     NaN      0.565446         NaN           NaN       NaN
# std      NaN      1.270529         NaN           NaN       NaN
# min      NaN      0.000000         NaN           NaN       NaN
# 25%      NaN      0.000000         NaN           NaN       NaN
# 50%      NaN      0.000000         NaN           NaN       NaN
# 75%      NaN      0.000000         NaN           NaN       NaN
# max      NaN      4.000000         NaN           NaN       NaN
#
#        FormId without Load#  Response Num                      Edid  \
# count                 74642  74642.000000                     74642
# unique                35288           NaN                     35455
# top                0001FB79           NaN  dunEldergleamT03Shared02
# freq                     56           NaN                        56
# mean                    NaN      1.199593                       NaN
# std                     NaN      0.602203                       NaN
# min                     NaN      1.000000                       NaN
# 25%                     NaN      1.000000                       NaN
# 50%                     NaN      1.000000                       NaN
# 75%                     NaN      1.000000                       NaN
# max                     NaN     13.000000                       NaN
#
#        Topic FormId                 Topic Edid                 Topic Text  \
# count         74642                      74642                      24736
# unique        17506                      17506                       5622
# top        0001F319  DialogueGenericSharedInfo  DialogueGenericSharedInfo
# freq           2010                       2010                       2010
# mean            NaN                        NaN                        NaN
# std             NaN                        NaN                        NaN
# min             NaN                        NaN                        NaN
# 25%             NaN                        NaN                        NaN
# 50%             NaN                        NaN                        NaN
# 75%             NaN                        NaN                        NaN
# max             NaN                        NaN                        NaN
#
#        Quest FormId       Quest Edid        Quest Name Category/Subtype  \
# count         74642            74642             54687            74642
# unique         1760             1760              1137               79
# top        00013EB3  DialogueGeneric  Generic dialogue     Topic/Custom
# freq          11199            11199             12196            23347
# mean            NaN              NaN               NaN              NaN
# std             NaN              NaN               NaN              NaN
# min             NaN              NaN               NaN              NaN
# 25%             NaN              NaN               NaN              NaN
# 50%             NaN              NaN               NaN              NaN
# 75%             NaN              NaN               NaN              NaN
# max             NaN              NaN               NaN              NaN
#
#         Emotion                                                Conditions  \
# count     74642                                                     53773
# unique        8                                                      9564
# top     Neutral  GetIsVoiceType: DefaultNPCVoiceTypes [FLST:0003B4A5] = 1
# freq      28836                                                       756
# mean        NaN                                                       NaN
# std         NaN                                                       NaN
# min         NaN                                                       NaN
# 25%         NaN                                                       NaN
# 50%         NaN                                                       NaN
# 75%         NaN                                                       NaN
# max         NaN                                                       NaN
#
#                        Bsa Name  \
# count                     74642
# unique                        1
# top     Skyrim - Voices_en0.bsa
# freq                      74642
# mean                        NaN
# std                         NaN
# min                         NaN
# 25%                         NaN
# 50%                         NaN
# 75%                         NaN
# max                         NaN
#
#                                                                                                                                                                  Full Path  \
# count                                                                                                                                                                74642
# unique                                                                                                                                                               74642
# top     C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa\sound\voice\skyrim.esm\maleoldkindly\mg07_mg07tolfdirforcegreet_000130da_1.fuz
# freq                                                                                                                                                                     1
# mean                                                                                                                                                                   NaN
# std                                                                                                                                                                    NaN
# min                                                                                                                                                                    NaN
# 25%                                                                                                                                                                    NaN
# 50%                                                                                                                                                                    NaN
# 75%                                                                                                                                                                    NaN
# max                                                                                                                                                                    NaN
#
#                                                                                   Base Path  \
# count                                                                                 74642
# unique                                                                                    1
# top     C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa
# freq                                                                                  74642
# mean                                                                                    NaN
# std                                                                                     NaN
# min                                                                                     NaN
# 25%                                                                                     NaN
# 50%                                                                                     NaN
# 75%                                                                                     NaN
# max                                                                                     NaN
#
#                                                                                   Path  \
# count                                                                            74642
# unique                                                                           74642
# top     sound\voice\skyrim.esm\maleoldkindly\mg07_mg07tolfdirforcegreet_000130da_1.fuz
# freq                                                                                 1
# mean                                                                               NaN
# std                                                                                NaN
# min                                                                                NaN
# 25%                                                                                NaN
# 50%                                                                                NaN
# 75%                                                                                NaN
# max                                                                                NaN
#
#                                         File Name Extensions Voice Type  \
# count                                       74642      74642      74642
# unique                                      43827          1        134
# top     duneldergl_duneldergleamt0_0001fb79_1.fuz       .fuz   malenord
# freq                                           56      74642       4453
# mean                                          NaN        NaN        NaN
# std                                           NaN        NaN        NaN
# min                                           NaN        NaN        NaN
# 25%                                           NaN        NaN        NaN
# 50%                                           NaN        NaN        NaN
# 75%                                           NaN        NaN        NaN
# max                                           NaN        NaN        NaN
#
#                  Prompt Dialogue 1 - English Dialogue 2 - English  \
# count              2987                74642                74642
# unique             1087                41088                41088
# top     (Remain silent)
# freq                 77                 1781                 1781
# mean                NaN                  NaN                  NaN
# std                 NaN                  NaN                  NaN
# min                 NaN                  NaN                  NaN
# 25%                 NaN                  NaN                  NaN
# 50%                 NaN                  NaN                  NaN
# 75%                 NaN                  NaN                  NaN
# max                 NaN                  NaN                  NaN
#
#                     Script Notes  \
# count                      26256
# unique                      6094
# top     Angry combat attack line
# freq                         678
# mean                         NaN
# std                          NaN
# min                          NaN
# 25%                          NaN
# 50%                          NaN
# 75%                          NaN
# max                          NaN
#
#                                                Edits  Keyword      StringId
# count                                           1193      0.0  74642.000000
# unique                                           708      NaN           NaN
# top     I'll take whatever ya got, after I kill you.      NaN           NaN
# freq                                              65      NaN           NaN
# mean                                             NaN      NaN  30468.828032
# std                                              NaN      NaN  20856.653934
# min                                              NaN      NaN      4.000000
# 25%                                              NaN      NaN   9852.000000
# 50%                                              NaN      NaN  29128.000000
# 75%                                              NaN      NaN  48195.750000
# max                                              NaN      NaN  75445.000000

# %%
df_all.head(1)['Full Path']
# Out:
# 26    C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa\sound\voice\skyrim.esm\maleoldkindly\mg07_mg07tolfdirforcegreet_000130da_1.fuz
# Name: Full Path, dtype: object

# %%
df_all.loc[df_all['Topic FormId']=='00035E10']
# Out:
#       State  Index      Plugin Last Modifier    FormId FormId without Load#  \
# 26      NaN      0  skyrim.esm    skyrim.esm  000130DA             000130DA
# 27      NaN      0  skyrim.esm    skyrim.esm  000130DA             000130DA
# 44796   NaN      0  skyrim.esm    skyrim.esm  000C2778             000C2778
#
#        Response Num        Edid Topic FormId  \
# 26              1.0  [000130DA]     00035E10
# 27              2.0  [000130DA]     00035E10
# 44796           1.0  [000C2778]     00035E10
#
#                              Topic Edid Topic Text Quest FormId Quest Edid  \
# 26     MG07TolfdirForcegreetBranchTopic        NaN     0001F257       MG07
# 27     MG07TolfdirForcegreetBranchTopic        NaN     0001F257       MG07
# 44796  MG07TolfdirForcegreetBranchTopic        NaN     0001F257       MG07
#
#                 Quest Name Category/Subtype  Emotion  \
# 26     The Staff of Magnus     Topic/Custom  Neutral
# 27     The Staff of Magnus     Topic/Custom  Neutral
# 44796  The Staff of Magnus     Topic/Custom  Puzzled
#
#                                                                                           Conditions  \
# 26     GetStage: "The Staff of Magnus" [QUST:0001F257] >= 50\nGetIsID: "Tolfdir" [NPC_:0001C19E] = 1
# 27     GetStage: "The Staff of Magnus" [QUST:0001F257] >= 50\nGetIsID: "Tolfdir" [NPC_:0001C19E] = 1
# 44796                                          GetStage: "The Staff of Magnus" [QUST:0001F257] >= 50
#
#                       Bsa Name  \
# 26     Skyrim - Voices_en0.bsa
# 27     Skyrim - Voices_en0.bsa
# 44796  Skyrim - Voices_en0.bsa
#
#                                                                                                                                                                 Full Path  \
# 26     C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa\sound\voice\skyrim.esm\maleoldkindly\mg07_mg07tolfdirforcegreet_000130da_1.fuz
# 27     C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa\sound\voice\skyrim.esm\maleoldkindly\mg07_mg07tolfdirforcegreet_000130da_2.fuz
# 44796  C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa\sound\voice\skyrim.esm\maleoldkindly\mg07_mg07tolfdirforcegreet_000c2778_1.fuz
#
#                                                                                  Base Path  \
# 26     C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa
# 27     C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa
# 44796  C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa
#
#                                                                                  Path  \
# 26     sound\voice\skyrim.esm\maleoldkindly\mg07_mg07tolfdirforcegreet_000130da_1.fuz
# 27     sound\voice\skyrim.esm\maleoldkindly\mg07_mg07tolfdirforcegreet_000130da_2.fuz
# 44796  sound\voice\skyrim.esm\maleoldkindly\mg07_mg07tolfdirforcegreet_000c2778_1.fuz
#
#                                        File Name Extensions     Voice Type  \
# 26     mg07_mg07tolfdirforcegreet_000130da_1.fuz       .fuz  maleoldkindly
# 27     mg07_mg07tolfdirforcegreet_000130da_2.fuz       .fuz  maleoldkindly
# 44796  mg07_mg07tolfdirforcegreet_000c2778_1.fuz       .fuz  maleoldkindly
#
#       Prompt                                          Dialogue 1 - English  \
# 26       NaN                              You survived! You have it, then?
# 27       NaN  Let's hope it's as powerful as the Psijics believe it to be.
# 44796    NaN                                      What are we waiting for?
#
#                                                Dialogue 2 - English  \
# 26                                 You survived! You have it, then?
# 27     Let's hope it's as powerful as the Psijics believe it to be.
# 44796                                      What are we waiting for?
#
#       Script Notes Edits  Keyword  StringId
# 26             NaN   NaN      NaN   25001.0
# 27             NaN   NaN      NaN   17544.0
# 44796          NaN   NaN      NaN   33274.0

# %%
df_all['Topic Text'].value_counts().head(10)
# Out:
# Topic Text
# DialogueGenericSharedInfo      2010
# CWSharedInfoStack               978
# Hello.                          376
# ShoutStartShort                 365
# What have you got for sale?     354
# ShoutStartLong                  348
# PushRoDa                        346
# ShoutEndShort                   339
# DialogueGenericHello            244
# DCETAttack                      240
# Name: count, dtype: int64

# %%
df_all['Prompt'].value_counts().head(10)
# Out:
# Prompt
# (Remain silent)                                                                    77
# I'd like to decorate my home.                                                      48
# Consider it done.                                                                  41
# What'll you give me for these?                                                     28
# Floor decorations. (400 gold)                                                      24
# I'll take you to the monster you're hunting. (Persuade)                            24
# You know what you have to do.                                                      19
# What can you tell me about yourself?                                               19
# Dead.                                                                              18
# I don't have time for this. I can get rough with you if I have to. (Intimidate)    18
# Name: count, dtype: int64

# %%
df_all['Category/Subtype'].value_counts()
# Out:
# Category/Subtype
# Topic/Custom                      23347
# Scene/Scene                       13151
# Miscellaneous/Hello                9368
# Miscellaneous/SharedInfo           8864
# Combat/Attack                      2476
#                                   ...
# Favors/FlyingMountLand                6
# Favors/FlyingMountCancelLand          6
# Miscellaneous/StandonFurniture        2
# Favor/Intimidate                      1
# Favor/Bribe                           1
# Name: count, Length: 79, dtype: int64

# %%
filtered_cols = ['FormId','Response Num', 'Topic Text','Quest FormId','Quest Name','Category/Subtype','Emotion','Voice Type','Prompt','Dialogue 1 - English']
df = df_all[filtered_cols]

df = df.loc[df['Topic Text'].notna()]
df = df.loc[(df['Quest Name']!='Generic dialogue')]
# Filter out cases where Topic Text just says CWSharedInfoStack and Prompt contains nothing
df = df.loc[~((df['Topic Text']=='CWSharedInfoStack') & (df['Prompt'].isna()))]

# Filter out cases where the player response is not in spoken English
# "Hello." is also removed as the responses from this short statement vary too wildly
excluded_topics = ['Hello.','ShoutStartShort','ShoutStartLong','PushRoDa','ShoutEndShort','DCETAttack','RelationshipAdoption_SharedInfos',
                   '(Invisible continue)','(Invisible Continue)','...','Shout2','Shout1b','CommandedHello','MS11','DLC1ThrallHellos',
                   'DialogueCarriageSystemIdle','DCETNoticeCorpse','(Sharedinfo)','TG01Hellos','TG09NDAttacks',
                   'RelationshipMarriagePostWeddingLoveInterestBlockingTopic','DA03Hello','(Invisible Continues Linked to Self)','TG08BHellos',
                   'BYOHRelationshipAdoptableOrphanable_SharedInfos','DLC1VQ07Attack','(Invisible Continue) Location of Attack',
                   'RelationshipAdoption_FGReceiveGiftTopic','DBNazirEvictionBranchTopic','DLC1VQ04Hellos','dunRannveigQSTSHARED01',
                   'T01Hellos','TG09NDDeaths','(Invisible Continue)(Forced Good bye) Time Limit to Attack',
                   '(Invisible Continue)(Forced Goodbye) Time Limit to Attack','(forcegreet)','(Invisible Continue) Difficulty based on Attack Dela',
                   '(Invisible Continue) Difficulty based on Attack Delta','TG09NDCombatToNormal','DB11AmaundJobDoneTopic','DB11EmperorPlayerResponse13']
df = df.loc[~(df['Topic Text'].isin(excluded_topics))]

# DialogueRiftenGoodbyes can just be set to Goodbye
df['Topic Text'] = np.where(df['Topic Text']=='DialogueRiftenGoodbyes','Goodbye.', df['Topic Text'])
# Where Topic Text = CWSharedInfoStack, the player's dialogue can be found in Prompt
df['Input'] = np.where(df['Topic Text']=='CWSharedInfoStack', df['Prompt'], df['Topic Text'])
print(df.shape[0])
df.head(2)
# Out:
# 17569
#       FormId  Response Num                    Topic Text Quest FormId  \
# 42  00013626           1.0  Where can I find fire salts?     0005331D
# 43  00013626           3.0  Where can I find fire salts?     0005331D
#
#             Quest Name Category/Subtype  Emotion Voice Type Prompt  \
# 42  Stoking the Flames     Topic/Custom     Fear  malebrute    NaN
# 43  Stoking the Flames     Topic/Custom  Neutral  malebrute    NaN
#
#                                                                                              Dialogue 1 - English  \
# 42  A flame atronach's body might provide fire salt. They're dangerous creatures that can be summoned by wizards.
# 43           Of course, it would be much easier to check with an alchemist. They occasionally have them for sale.
#
#                            Input
# 42  Where can I find fire salts?
# 43  Where can I find fire salts?

# %%
def group_dialogue(df):
    '''Group dialogue into a single response

    NPC responses are often split across multiple rows
    Unique responses can be identified by FormId, and grouped back into a single response via the order of Response Num
    '''
    grouped = df.groupby('FormId')
    processed_data = []
    seen_entries = set()

    for form_id, group in grouped:
        sorted_group = group.sort_values('Response Num')
        
        # Join the dialogues
        dialogues = ' '.join(sorted_group['Dialogue 1 - English'].tolist())
        
        # Get the player's input
        topic_text = sorted_group['Topic Text'].iloc[0]
        
        # Save the player / NPC interaction in an Alpaca style data format
        entry = {
            "instruction": "Generate dialogue in the style of Skyrim.",
            "input": topic_text,
            "output": dialogues
        }
        
        # Check if the entry is unique based on 'input' and 'output'
        entry_tuple = (entry['input'], entry['output'])
        if entry_tuple not in seen_entries:
            processed_data.append(entry)
            seen_entries.add(entry_tuple)

    return processed_data

# %%
data = group_dialogue(df)
print(len(data))
data[0:5]
# Out:
# 8830
# [{'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Where can I find fire salts?',
#   'output': "A flame atronach's body might provide fire salt. They're dangerous creatures that can be summoned by wizards. Of course, it would be much easier to check with an alchemist. They occasionally have them for sale."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Sorry to hear that.',
#   'output': "Shutting this place down would dishonor my family's heritage, but what other choice will I have?"},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "I'll get some for you.",
#   'output': 'You will? Thank you! Ten pinches of fire salts should give me all I need to bring this forge back to life.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Goodbye.',
#   'output': "Return anytime. You're quite welcome here."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Goodbye.',
#   'output': 'Remember, nothing but genuine fire salts will do... the forge knows the difference.'}]

# %%
with open('skyrim_alpaca_style_dataset.json', 'w') as json_file:
    json.dump(data, json_file, indent=4)
