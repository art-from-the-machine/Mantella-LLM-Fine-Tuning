# %% [markdown]
# # Import & Setup

# %%
import pandas as pd
import numpy as np
import json
pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth', None)

# %% [markdown]
# # Data

# %% [markdown]
# `LazyVoiceFinder_export.csv` contains a full export of all Skyrim + DLC dialogue exchanges.
# To generate this dataset:
# 1. Download [Lazy Voice Finder](https://www.nexusmods.com/skyrimspecialedition/mods/8619)
# 2. Set the game to Skyrim in LazyVoiceFinder.exe
# 3. Right-click any column -> Unhide Columns -> (All Columns)
# 4. Go to File -> Export CSV File...

# %%
df_all = pd.read_csv('LazyVoiceFinder_export.csv', low_memory=False)
df_all = df_all.loc[~(df_all['State'].isin(['Bad File Name, No Dialogue','No Voice File']))]
df_all = df_all.loc[(df_all['Dialogue 1 - English'].notna()) & (df_all['Dialogue 1 - English']!='')]
print(df_all.shape)
df_all.head()
# Out:
# (74642, 31)
#    State  Index      Plugin Last Modifier    FormId FormId without Load#  \
# 26   NaN      0  skyrim.esm    skyrim.esm  000130DA             000130DA
# 27   NaN      0  skyrim.esm    skyrim.esm  000130DA             000130DA
# 28   NaN      0  skyrim.esm    skyrim.esm  00013113             00013113
# 29   NaN      0  skyrim.esm    skyrim.esm  00013114             00013114
# 30   NaN      0  skyrim.esm    skyrim.esm  00013115             00013115
#
#     Response Num        Edid Topic FormId                        Topic Edid  \
# 26           1.0  [000130DA]     00035E10  MG07TolfdirForcegreetBranchTopic
# 27           2.0  [000130DA]     00035E10  MG07TolfdirForcegreetBranchTopic
# 28           1.0  [00013113]     0001310D                        [0001310D]
# 29           1.0  [00013114]     0001310C                        [0001310C]
# 30           1.0  [00013115]     0001310A                        [0001310A]
#
#    Topic Text Quest FormId Quest Edid           Quest Name Category/Subtype  \
# 26        NaN     0001F257       MG07  The Staff of Magnus     Topic/Custom
# 27        NaN     0001F257       MG07  The Staff of Magnus     Topic/Custom
# 28        NaN     00036192      MQ203        Alduin's Wall      Scene/Scene
# 29        NaN     00036192      MQ203        Alduin's Wall      Scene/Scene
# 30        NaN     00036192      MQ203        Alduin's Wall      Scene/Scene
#
#      Emotion  \
# 26   Neutral
# 27   Neutral
# 28  Surprise
# 29     Happy
# 30  Surprise
#
#                                                                                        Conditions  \
# 26  GetStage: "The Staff of Magnus" [QUST:0001F257] >= 50\nGetIsID: "Tolfdir" [NPC_:0001C19E] = 1
# 27  GetStage: "The Staff of Magnus" [QUST:0001F257] >= 50\nGetIsID: "Tolfdir" [NPC_:0001C19E] = 1
# 28                                                                                            NaN
# 29                                                                                            NaN
# 30                                                                                            NaN
#
#                    Bsa Name  \
# 26  Skyrim - Voices_en0.bsa
# 27  Skyrim - Voices_en0.bsa
# 28  Skyrim - Voices_en0.bsa
# 29  Skyrim - Voices_en0.bsa
# 30  Skyrim - Voices_en0.bsa
#
#                                                                                                                                                              Full Path  \
# 26  C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa\sound\voice\skyrim.esm\maleoldkindly\mg07_mg07tolfdirforcegreet_000130da_1.fuz
# 27  C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa\sound\voice\skyrim.esm\maleoldkindly\mg07_mg07tolfdirforcegreet_000130da_2.fuz
# 28               C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa\sound\voice\skyrim.esm\femaleuniquedelphine\mq203__00013113_1.fuz
# 29               C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa\sound\voice\skyrim.esm\femaleuniquedelphine\mq203__00013114_1.fuz
# 30                   C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa\sound\voice\skyrim.esm\maleuniqueesbern\mq203__00013115_1.fuz
#
#                                                                               Base Path  \
# 26  C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa
# 27  C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa
# 28  C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa
# 29  C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa
# 30  C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa
#
#                                                                               Path  \
# 26  sound\voice\skyrim.esm\maleoldkindly\mg07_mg07tolfdirforcegreet_000130da_1.fuz
# 27  sound\voice\skyrim.esm\maleoldkindly\mg07_mg07tolfdirforcegreet_000130da_2.fuz
# 28               sound\voice\skyrim.esm\femaleuniquedelphine\mq203__00013113_1.fuz
# 29               sound\voice\skyrim.esm\femaleuniquedelphine\mq203__00013114_1.fuz
# 30                   sound\voice\skyrim.esm\maleuniqueesbern\mq203__00013115_1.fuz
#
#                                     File Name Extensions  \
# 26  mg07_mg07tolfdirforcegreet_000130da_1.fuz       .fuz
# 27  mg07_mg07tolfdirforcegreet_000130da_2.fuz       .fuz
# 28                      mq203__00013113_1.fuz       .fuz
# 29                      mq203__00013114_1.fuz       .fuz
# 30                      mq203__00013115_1.fuz       .fuz
#
#               Voice Type Prompt  \
# 26         maleoldkindly    NaN
# 27         maleoldkindly    NaN
# 28  femaleuniquedelphine    NaN
# 29  femaleuniquedelphine    NaN
# 30      maleuniqueesbern    NaN
#
#                                             Dialogue 1 - English  \
# 26                              You survived! You have it, then?
# 27  Let's hope it's as powerful as the Psijics believe it to be.
# 28                    That's done it! Look, it's coming to life!
# 29                             You did it. There's the entrance!
# 30                 There's no telling what we might find inside!
#
#                                             Dialogue 2 - English  \
# 26                              You survived! You have it, then?
# 27  Let's hope it's as powerful as the Psijics believe it to be.
# 28                    That's done it! Look, it's coming to life!
# 29                             You did it. There's the entrance!
# 30                 There's no telling what we might find inside!
#
#                                            Script Notes Edits  Keyword  \
# 26                                                  NaN   NaN      NaN
# 27                                                  NaN   NaN      NaN
# 28  awe breaking through Delphine's usual jaded persona   NaN      NaN
# 29                                                  NaN   NaN      NaN
# 30                                            excitedly   NaN      NaN
#
#     StringId
# 26   25001.0
# 27   17544.0
# 28   60023.0
# 29   49515.0
# 30   30760.0

# %%
df_all.describe(include='all')
# Out:
#        State         Index      Plugin Last Modifier    FormId  \
# count      0  74642.000000       74642         74642     74642
# unique     0           NaN           4             5     35455
# top      NaN           NaN  skyrim.esm    skyrim.esm  0001FB79
# freq     NaN           NaN       61165         59802        56
# mean     NaN      0.565446         NaN           NaN       NaN
# std      NaN      1.270529         NaN           NaN       NaN
# min      NaN      0.000000         NaN           NaN       NaN
# 25%      NaN      0.000000         NaN           NaN       NaN
# 50%      NaN      0.000000         NaN           NaN       NaN
# 75%      NaN      0.000000         NaN           NaN       NaN
# max      NaN      4.000000         NaN           NaN       NaN
#
#        FormId without Load#  Response Num                      Edid  \
# count                 74642  74642.000000                     74642
# unique                35288           NaN                     35455
# top                0001FB79           NaN  dunEldergleamT03Shared02
# freq                     56           NaN                        56
# mean                    NaN      1.199593                       NaN
# std                     NaN      0.602203                       NaN
# min                     NaN      1.000000                       NaN
# 25%                     NaN      1.000000                       NaN
# 50%                     NaN      1.000000                       NaN
# 75%                     NaN      1.000000                       NaN
# max                     NaN     13.000000                       NaN
#
#        Topic FormId                 Topic Edid                 Topic Text  \
# count         74642                      74642                      24736
# unique        17506                      17506                       5622
# top        0001F319  DialogueGenericSharedInfo  DialogueGenericSharedInfo
# freq           2010                       2010                       2010
# mean            NaN                        NaN                        NaN
# std             NaN                        NaN                        NaN
# min             NaN                        NaN                        NaN
# 25%             NaN                        NaN                        NaN
# 50%             NaN                        NaN                        NaN
# 75%             NaN                        NaN                        NaN
# max             NaN                        NaN                        NaN
#
#        Quest FormId       Quest Edid        Quest Name Category/Subtype  \
# count         74642            74642             54687            74642
# unique         1760             1760              1137               79
# top        00013EB3  DialogueGeneric  Generic dialogue     Topic/Custom
# freq          11199            11199             12196            23347
# mean            NaN              NaN               NaN              NaN
# std             NaN              NaN               NaN              NaN
# min             NaN              NaN               NaN              NaN
# 25%             NaN              NaN               NaN              NaN
# 50%             NaN              NaN               NaN              NaN
# 75%             NaN              NaN               NaN              NaN
# max             NaN              NaN               NaN              NaN
#
#         Emotion                                                Conditions  \
# count     74642                                                     53773
# unique        8                                                      9564
# top     Neutral  GetIsVoiceType: DefaultNPCVoiceTypes [FLST:0003B4A5] = 1
# freq      28836                                                       756
# mean        NaN                                                       NaN
# std         NaN                                                       NaN
# min         NaN                                                       NaN
# 25%         NaN                                                       NaN
# 50%         NaN                                                       NaN
# 75%         NaN                                                       NaN
# max         NaN                                                       NaN
#
#                        Bsa Name  \
# count                     74642
# unique                        1
# top     Skyrim - Voices_en0.bsa
# freq                      74642
# mean                        NaN
# std                         NaN
# min                         NaN
# 25%                         NaN
# 50%                         NaN
# 75%                         NaN
# max                         NaN
#
#                                                                                                                                                                  Full Path  \
# count                                                                                                                                                                74642
# unique                                                                                                                                                               74642
# top     C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa\sound\voice\skyrim.esm\maleoldkindly\mg07_mg07tolfdirforcegreet_000130da_1.fuz
# freq                                                                                                                                                                     1
# mean                                                                                                                                                                   NaN
# std                                                                                                                                                                    NaN
# min                                                                                                                                                                    NaN
# 25%                                                                                                                                                                    NaN
# 50%                                                                                                                                                                    NaN
# 75%                                                                                                                                                                    NaN
# max                                                                                                                                                                    NaN
#
#                                                                                   Base Path  \
# count                                                                                 74642
# unique                                                                                    1
# top     C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa
# freq                                                                                  74642
# mean                                                                                    NaN
# std                                                                                     NaN
# min                                                                                     NaN
# 25%                                                                                     NaN
# 50%                                                                                     NaN
# 75%                                                                                     NaN
# max                                                                                     NaN
#
#                                                                                   Path  \
# count                                                                            74642
# unique                                                                           74642
# top     sound\voice\skyrim.esm\maleoldkindly\mg07_mg07tolfdirforcegreet_000130da_1.fuz
# freq                                                                                 1
# mean                                                                               NaN
# std                                                                                NaN
# min                                                                                NaN
# 25%                                                                                NaN
# 50%                                                                                NaN
# 75%                                                                                NaN
# max                                                                                NaN
#
#                                         File Name Extensions Voice Type  \
# count                                       74642      74642      74642
# unique                                      43827          1        134
# top     duneldergl_duneldergleamt0_0001fb79_1.fuz       .fuz   malenord
# freq                                           56      74642       4453
# mean                                          NaN        NaN        NaN
# std                                           NaN        NaN        NaN
# min                                           NaN        NaN        NaN
# 25%                                           NaN        NaN        NaN
# 50%                                           NaN        NaN        NaN
# 75%                                           NaN        NaN        NaN
# max                                           NaN        NaN        NaN
#
#                  Prompt Dialogue 1 - English Dialogue 2 - English  \
# count              2987                74642                74642
# unique             1087                41088                41088
# top     (Remain silent)
# freq                 77                 1781                 1781
# mean                NaN                  NaN                  NaN
# std                 NaN                  NaN                  NaN
# min                 NaN                  NaN                  NaN
# 25%                 NaN                  NaN                  NaN
# 50%                 NaN                  NaN                  NaN
# 75%                 NaN                  NaN                  NaN
# max                 NaN                  NaN                  NaN
#
#                     Script Notes  \
# count                      26256
# unique                      6094
# top     Angry combat attack line
# freq                         678
# mean                         NaN
# std                          NaN
# min                          NaN
# 25%                          NaN
# 50%                          NaN
# 75%                          NaN
# max                          NaN
#
#                                                Edits  Keyword      StringId
# count                                           1193      0.0  74642.000000
# unique                                           708      NaN           NaN
# top     I'll take whatever ya got, after I kill you.      NaN           NaN
# freq                                              65      NaN           NaN
# mean                                             NaN      NaN  30468.828032
# std                                              NaN      NaN  20856.653934
# min                                              NaN      NaN      4.000000
# 25%                                              NaN      NaN   9852.000000
# 50%                                              NaN      NaN  29128.000000
# 75%                                              NaN      NaN  48195.750000
# max                                              NaN      NaN  75445.000000

# %%
df_all.head(1)['Full Path']
# Out:
# 26    C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa\sound\voice\skyrim.esm\maleoldkindly\mg07_mg07tolfdirforcegreet_000130da_1.fuz
# Name: Full Path, dtype: object

# %%
df_all.loc[df_all['Topic FormId']=='00035E10']
# Out:
#       State  Index      Plugin Last Modifier    FormId FormId without Load#  \
# 26      NaN      0  skyrim.esm    skyrim.esm  000130DA             000130DA
# 27      NaN      0  skyrim.esm    skyrim.esm  000130DA             000130DA
# 44796   NaN      0  skyrim.esm    skyrim.esm  000C2778             000C2778
#
#        Response Num        Edid Topic FormId  \
# 26              1.0  [000130DA]     00035E10
# 27              2.0  [000130DA]     00035E10
# 44796           1.0  [000C2778]     00035E10
#
#                              Topic Edid Topic Text Quest FormId Quest Edid  \
# 26     MG07TolfdirForcegreetBranchTopic        NaN     0001F257       MG07
# 27     MG07TolfdirForcegreetBranchTopic        NaN     0001F257       MG07
# 44796  MG07TolfdirForcegreetBranchTopic        NaN     0001F257       MG07
#
#                 Quest Name Category/Subtype  Emotion  \
# 26     The Staff of Magnus     Topic/Custom  Neutral
# 27     The Staff of Magnus     Topic/Custom  Neutral
# 44796  The Staff of Magnus     Topic/Custom  Puzzled
#
#                                                                                           Conditions  \
# 26     GetStage: "The Staff of Magnus" [QUST:0001F257] >= 50\nGetIsID: "Tolfdir" [NPC_:0001C19E] = 1
# 27     GetStage: "The Staff of Magnus" [QUST:0001F257] >= 50\nGetIsID: "Tolfdir" [NPC_:0001C19E] = 1
# 44796                                          GetStage: "The Staff of Magnus" [QUST:0001F257] >= 50
#
#                       Bsa Name  \
# 26     Skyrim - Voices_en0.bsa
# 27     Skyrim - Voices_en0.bsa
# 44796  Skyrim - Voices_en0.bsa
#
#                                                                                                                                                                 Full Path  \
# 26     C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa\sound\voice\skyrim.esm\maleoldkindly\mg07_mg07tolfdirforcegreet_000130da_1.fuz
# 27     C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa\sound\voice\skyrim.esm\maleoldkindly\mg07_mg07tolfdirforcegreet_000130da_2.fuz
# 44796  C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa\sound\voice\skyrim.esm\maleoldkindly\mg07_mg07tolfdirforcegreet_000c2778_1.fuz
#
#                                                                                  Base Path  \
# 26     C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa
# 27     C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa
# 44796  C:\Games\Steam\steamapps\common\Skyrim Special Edition\Data\Skyrim - Voices_en0.bsa
#
#                                                                                  Path  \
# 26     sound\voice\skyrim.esm\maleoldkindly\mg07_mg07tolfdirforcegreet_000130da_1.fuz
# 27     sound\voice\skyrim.esm\maleoldkindly\mg07_mg07tolfdirforcegreet_000130da_2.fuz
# 44796  sound\voice\skyrim.esm\maleoldkindly\mg07_mg07tolfdirforcegreet_000c2778_1.fuz
#
#                                        File Name Extensions     Voice Type  \
# 26     mg07_mg07tolfdirforcegreet_000130da_1.fuz       .fuz  maleoldkindly
# 27     mg07_mg07tolfdirforcegreet_000130da_2.fuz       .fuz  maleoldkindly
# 44796  mg07_mg07tolfdirforcegreet_000c2778_1.fuz       .fuz  maleoldkindly
#
#       Prompt                                          Dialogue 1 - English  \
# 26       NaN                              You survived! You have it, then?
# 27       NaN  Let's hope it's as powerful as the Psijics believe it to be.
# 44796    NaN                                      What are we waiting for?
#
#                                                Dialogue 2 - English  \
# 26                                 You survived! You have it, then?
# 27     Let's hope it's as powerful as the Psijics believe it to be.
# 44796                                      What are we waiting for?
#
#       Script Notes Edits  Keyword  StringId
# 26             NaN   NaN      NaN   25001.0
# 27             NaN   NaN      NaN   17544.0
# 44796          NaN   NaN      NaN   33274.0

# %%
df_all['Topic Text'].value_counts().head(10)
# Out:
# Topic Text
# DialogueGenericSharedInfo      2010
# CWSharedInfoStack               978
# Hello.                          376
# ShoutStartShort                 365
# What have you got for sale?     354
# ShoutStartLong                  348
# PushRoDa                        346
# ShoutEndShort                   339
# DialogueGenericHello            244
# DCETAttack                      240
# Name: count, dtype: int64

# %%
df_all['Prompt'].value_counts().head(10)
# Out:
# Prompt
# (Remain silent)                                                                    77
# I'd like to decorate my home.                                                      48
# Consider it done.                                                                  41
# What'll you give me for these?                                                     28
# Floor decorations. (400 gold)                                                      24
# I'll take you to the monster you're hunting. (Persuade)                            24
# You know what you have to do.                                                      19
# What can you tell me about yourself?                                               19
# Dead.                                                                              18
# I don't have time for this. I can get rough with you if I have to. (Intimidate)    18
# Name: count, dtype: int64

# %%
df_all['Category/Subtype'].value_counts()
# Out:
# Category/Subtype
# Topic/Custom                      23347
# Scene/Scene                       13151
# Miscellaneous/Hello                9368
# Miscellaneous/SharedInfo           8864
# Combat/Attack                      2476
#                                   ...
# Favors/FlyingMountLand                6
# Favors/FlyingMountCancelLand          6
# Miscellaneous/StandonFurniture        2
# Favor/Intimidate                      1
# Favor/Bribe                           1
# Name: count, Length: 79, dtype: int64

# %%
filtered_cols = ['FormId','Response Num', 'Topic Text','Quest FormId','Quest Name','Category/Subtype','Emotion','Voice Type','Prompt','Dialogue 1 - English']
df = df_all[filtered_cols]

df = df.loc[df['Topic Text'].notna()]
df = df.loc[(df['Quest Name']!='Generic dialogue')]
# Filter out cases where Topic Text just says CWSharedInfoStack and Prompt contains nothing
df = df.loc[~((df['Topic Text']=='CWSharedInfoStack') & (df['Prompt'].isna()))]

# Filter out cases where the player response is not in spoken English
# "Hello." is also removed as the responses from this short statement vary too wildly
excluded_topics = ['Hello.','ShoutStartShort','ShoutStartLong','PushRoDa','ShoutEndShort','DCETAttack','RelationshipAdoption_SharedInfos',
                   '(Invisible continue)','(Invisible Continue)','...','Shout2','Shout1b','CommandedHello','MS11','DLC1ThrallHellos',
                   'DialogueCarriageSystemIdle','DCETNoticeCorpse','(Sharedinfo)','TG01Hellos','TG09NDAttacks',
                   'RelationshipMarriagePostWeddingLoveInterestBlockingTopic','DA03Hello','(Invisible Continues Linked to Self)','TG08BHellos',
                   'BYOHRelationshipAdoptableOrphanable_SharedInfos','DLC1VQ07Attack','(Invisible Continue) Location of Attack',
                   'RelationshipAdoption_FGReceiveGiftTopic','DBNazirEvictionBranchTopic','DLC1VQ04Hellos','dunRannveigQSTSHARED01',
                   'T01Hellos','TG09NDDeaths','(Invisible Continue)(Forced Good bye) Time Limit to Attack',
                   '(Invisible Continue)(Forced Goodbye) Time Limit to Attack','(forcegreet)','(Invisible Continue) Difficulty based on Attack Dela',
                   '(Invisible Continue) Difficulty based on Attack Delta','TG09NDCombatToNormal','DB11AmaundJobDoneTopic','DB11EmperorPlayerResponse13']
df = df.loc[~(df['Topic Text'].isin(excluded_topics))]

# DialogueRiftenGoodbyes can just be set to Goodbye
df['Topic Text'] = np.where(df['Topic Text']=='DialogueRiftenGoodbyes','Goodbye.', df['Topic Text'])
# Where Topic Text = CWSharedInfoStack, the player's dialogue can be found in Prompt
df['Input'] = np.where(df['Topic Text']=='CWSharedInfoStack', df['Prompt'], df['Topic Text'])
print(df.shape[0])
df.head(2)
# Out:
# 17569
#       FormId  Response Num                    Topic Text Quest FormId  \
# 42  00013626           1.0  Where can I find fire salts?     0005331D
# 43  00013626           3.0  Where can I find fire salts?     0005331D
#
#             Quest Name Category/Subtype  Emotion Voice Type Prompt  \
# 42  Stoking the Flames     Topic/Custom     Fear  malebrute    NaN
# 43  Stoking the Flames     Topic/Custom  Neutral  malebrute    NaN
#
#                                                                                              Dialogue 1 - English  \
# 42  A flame atronach's body might provide fire salt. They're dangerous creatures that can be summoned by wizards.
# 43           Of course, it would be much easier to check with an alchemist. They occasionally have them for sale.
#
#                            Input
# 42  Where can I find fire salts?
# 43  Where can I find fire salts?

# %%
def group_dialogue(df):
    '''Group dialogue into a single response

    NPC responses are often split across multiple rows
    Unique responses can be identified by FormId, and grouped back into a single response via the order of Response Num
    '''
    grouped = df.groupby('FormId')
    processed_data = []
    seen_entries = set()

    for form_id, group in grouped:
        sorted_group = group.sort_values('Response Num')
        
        # Join the dialogues
        dialogues = ' '.join(sorted_group['Dialogue 1 - English'].tolist())
        
        # Get the player's input
        topic_text = sorted_group['Topic Text'].iloc[0]
        
        # Save the player / NPC interaction in an Alpaca style data format
        entry = {
            "instruction": "Generate dialogue in the style of Skyrim.",
            "input": topic_text,
            "output": dialogues
        }
        
        # Check if the entry is unique based on 'input' and 'output'
        entry_tuple = (entry['input'], entry['output'])
        if entry_tuple not in seen_entries:
            processed_data.append(entry)
            seen_entries.add(entry_tuple)

    return processed_data

# %%
data = group_dialogue(df)
print(len(data))
data
# Out:
# 8830
# [{'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Where can I find fire salts?',
#   'output': "A flame atronach's body might provide fire salt. They're dangerous creatures that can be summoned by wizards. Of course, it would be much easier to check with an alchemist. They occasionally have them for sale."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Sorry to hear that.',
#   'output': "Shutting this place down would dishonor my family's heritage, but what other choice will I have?"},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "I'll get some for you.",
#   'output': 'You will? Thank you! Ten pinches of fire salts should give me all I need to bring this forge back to life.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Goodbye.',
#   'output': "Return anytime. You're quite welcome here."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Goodbye.',
#   'output': 'Remember, nothing but genuine fire salts will do... the forge knows the difference.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Goodbye.',
#   'output': 'If you need any more smithing work, come see me again.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'That was from Brynjolf. Get the message?',
#   'output': "I can't believe you did that. You people are monsters! You demand payment for protection and you can't even protect yourselves. Here, take your coin and tell Brynjolf to leave us alone."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Heard any rumors lately?',
#   'output': 'There have been whispers. A boy, up in Windhelm, name of Aventus Aretino. Been trying to contact... the Dark Brotherhood.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Have you heard any rumors lately?',
#   'output': "Lucan at the Riverwood Trader had his store broken into the other night. Oddly enough, barely anything's been stolen."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Heard any rumors lately?',
#   'output': 'Nobody trusts those mages, way up north in their college. Gods only know what they do up there.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'What would you ask of me?',
#   'output': 'Your fealty is precious to me. I will make good use of it. You bear my ring.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "Didn't I just kill you?",
#   'output': "And skillfully, too. I've been watching you for ages, it seems. You have the makings of a fine hunter. You may even be my champion. Perhaps. "},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Are you Hircine?',
#   'output': 'I am the spirit of the hunt, just one glimpse of the glorious stalker that your kind calls Hircine.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'I did as you asked.',
#   'output': "And found my favor. That skin will serve you well, child.  Look more closely at it. My glories shall protect you from all this world's grievances.  Good hunting. "},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "He's done me no wrong. I won't kill him.",
#   'output': 'There is no retribution in the hunt. It is not vengeance I seek, but the blood course of a living hunt. There are others who would gladly accept my favor.  They will hunt him while you delay. Your choice. '},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'It shall be done as you ask.',
#   'output': "Fly, my hunter. There are others who vie for my favor. A bit of competition. Don't dally while the prey flees. "},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Will you remove the curse from this ring?',
#   'output': 'I may consider it. But you must first do a service for my glory.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Wait here.',
#   'output': 'All right. All right. All right. All right. All right.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': '
},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'General Tullius ordered my execution. Why would I want to help him?',
#   'output': "I don't blame you for being angry about it. I would be, too, in your shoes. I don't blame you for being angry about it. I would be, too, in your shoes. But it was all a mistake. You weren't supposed to be on that cart with those Stormcloak traitors. But it was all a mistake. You weren't supposed to be on that cart with those Stormcloak traitors. And the Imperial Legion needs your help, especially now, with that dragon out there somewhere, and Ulfric back on the loose. And the Imperial Legion needs your help, especially now, with that dragon out there somewhere, and Ulfric back on the loose."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'It will be done.',
#   'output': 'Talos guide you, lad.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'It will be done.',
#   'output': 'Talos guide you, lass.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'I work for the honor of the Companions.',
#   'output': "Lad, I know what you've been up to."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "Aela and I work to avenge Skjor's death.",
#   'output': 'Your hearts are full of grief, and my own weeps at the loss of Skjor.  But his death was avenged long ago. You have taken more lives than honor demanded. The cycle of retaliation may continue for some time. '},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'CWSharedInfoStack',
#   'output': "Good. You've got real fire in you. I like that... Talos guide you. Good. You've got real fire in you. I like that... Talos guide you."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Lead on then.',
#   'output': "I'll meet you outside!"},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "I don't need a guide.",
#   'output': "Oh, really? You're just like my brother. Fine, but if you change your mind, I'll be right here."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'I rescued <Alias=Victim>.',
#   'output': "So I hear. You've brought honor to the Companions and yourself. So I hear. You've brought honor to the Companions and yourself."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'What are the Sacred Trials?',
#   'output': "It's an old Nord Tradition, a test to prove your worth in the eyes of Kyne. Show that you're a hunter and no simple butcher. Kyne teaches us to respect the beasts and blesses the hunter who will face their champions. True Nord hunters are those who survive the Trials."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "Not me. I don't believe in the Divines.",
#   'output': "Good. This is Skyrim, and we should honor the old ways. These foreigners don't even respect their own gods, much less Kyne and her Sacred Trials."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "What's wrong with the Divines?",
#   'output': "They're stolen idols! Imposter gods, sold by silver tongues. No thank you. Froki will not forget Kyne, or her Sacred Trials."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Tell me about Kyne.',
#   'output': "Those sycophants in the Temple would call her Kynareth. Just a pale shadow of the truth, like all the Temple Divines. Kyne! Blessed Warrior-Wife. Shor's widow, sacred to any true Nord hunter. She's the mother of men and beasts, and her veil is the storm."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'What do I need to do?',
#   'output': "I'll anoint you with the symbol of the wolf, the crab and the skeever. This will compel the guardian to appear when you reach his lair."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "I'm not interested.",
#   'output': "That's what an old man gets for thinking the younger generation might be interested in learning some honor."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Yes. Tell me what to do.',
#   'output': 'You must defeat guardian beasts, blessed by Kyne.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'What do you have there?',
#   'output': 'Hey! You dropped this back there.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "I'm here about Goldenglow Estate.",
#   'output': "I don't deal in land or property. Now, if you're looking for goods, you've come to the right person."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'I was right there. He almost killed me.',
#   'output': "I'm so sorry. I hope the Eight give you more peace in the future."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "Actually, I'm not sure. I need to think about it.",
#   'output': "I see... Well, the Legion will still be here when you change your mind. Rikke believes in you. And I'm starting to see why. Consider this. What greater glory than to serve the Emperor and his citizens here in Skyrim, in these days of greatest need?"},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "I'm ready to take the Oath.",
#   'output': 'Well, then. Repeat after me. "Upon my honor I do swear undying loyalty to the Emperor, Titus Mede II..."'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "I'm ready to take the oath.",
#   'output': 'Changed your mind? Decided you want to soldier for the Empire after all?'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'DBDawnstarDoorPlayerResponse1',
#   'output': 'Welcome home.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "Actually, I'm looking for this old guy hiding out in Riften.",
#   'output': "Expecting free information, eh? Help me deal with business first, then we'll see how I can help you. Besides, you look like your pockets are a little light on coin, am I right?"},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Hold on - I just wanted some information.',
#   'output': "And I'm busy. You help me out, and I'll help you out. That's just how it is."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'This will be easier without you getting in my way.',
#   'output': "Well, I was only trying to help. Fine, I'll just save myself then. Thank you for letting me out of that cage."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'I can handle this on my own.',
#   'output': "Well, I... If you're sure... I'll just be on my way then. Please do be careful, and thank you."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'You should get yourself to safety.',
#   'output': "Don't you need my help?"},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "Let me leave with the books, and there won't be any more trouble. (Persuade)",
#   'output': "Fine. Take them and be gone. Never return here, or else you'll face my full wrath."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'A guardian skeever? Are you serious?',
#   'output': "Don't mock it, pup. Even the lowliest beasts can kill the weak and arrogant. We'll try more powerful enemies next, if you survive this."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'What do I need to do?',
#   'output': "Return when you've defeated the guardian wolf, crab and skeever."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Consider yourself hired. (<global=hirelinggold>)',
#   'output': "You seem to be a little short on coin. Come back and see me when you've got the gold. You seem to be a little short on coin. Come back and see me when you've got the gold. You seem to be a little short on coin. Come back and see me when you've got the gold. You seem to be a little short on coin. Come back and see me when you've got the gold. You seem to be a little short on coin. Come back and see me when you've got the gold. You seem to be a little short on coin. Come back and see me when you've got the gold."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Consider yourself hired. (<global=hirelinggold>)',
#   'output': 'You have chosen wisely. Lead on, and I shall follow.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Consider yourself hired. (<global=hirelinggold>)',
#   'output': 'What dangers and wonders shall we discover in the frozen wastes? I can hardly wait to find out!'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "What will I face in the Pilgrim's Path?",
#   'output': "I wish I could help you, but I've been a prisoner in this very chamber for the last quarter century. The only possible help I've come across are the remains of some poor fellow who was trying to follow in your footsteps. Perhaps his journal can help?"},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "You're right. I could use some help.",
#   'output': 'I shall do my best.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "I'm ready for my first assignment.",
#   'output': 'Welcome to the Legion, auxiliary. Listen up.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Dead.',
#   'output': "Then... it's over and my death wasn't in vain. I owe you a great deal, Nightingale."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'I have the Key.',
#   'output': "The Key! You have the Skeleton Key! I never thought I'd see it again. And Mercer Frey?"},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'I did this for Nocturnal.',
#   'output': "That's quite a noble sentiment for someone in our... well, in your line of work. My only regret is that you had to undertake this task alone."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'I heard you know about Elder Scrolls.',
#   'output': 'Elder Scrolls. Indeed. But I cannot go to it, not poor Septimus, for I... I have arisen beyond its grasp. The Empire. They absconded with them. Or so they think. The ones they saw. The ones they thought they saw. I know of one. Forgotten. Sequestered.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "I've brought all the blood you require.",
#   'output': 'I can almost... hear them. I feel their life energy. Come, I will make the mixture.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "If you don't get away from me right now, I may kill you myself.",
#   'output': 'I was only trying to help you, you know! I hope the Caller turns you inside out!'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Never mind. Forget I mentioned it.',
#   'output': 'Hmph.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'You will die now.',
#   'output': 'That remains to be seen.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'This is what you want? To slave for others? What about your own destiny?',
#   'output': "Boethiah talks about leaving your mark, a sign of your passing.... Well, you can make a mark on the world without treachery and murder. Whenever a man's life is saved by armor made with these hands, these hands have changed that man's destiny and his family's. So you can tell that heartless Daedra bitch I'm done doing her dirty work. Mind my words or I'll mind them for you: I'm slave to no man, no god, and no Daedra."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input':
'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Do you have any sweep jobs?',
#   'output': 'Just got a tip on this house... should be stuffed with loot. Care to head over there and find out?'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Do you have any sweep jobs?',
#   'output': 'Got a message from one of my people that this place just came into some coin. Should be a good target. Want to take it?'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Do you have any sweep jobs?',
#   'output': 'Someone with connections to our Guild wants us to hit this place and send a message by clearing it of valuables. You want to handle it?'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Do you have any sweep jobs?',
#   'output': 'Good timing. The people in this home recently got one of your fellow Guild mates sent to jail. How about you make them pay for it.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Do you have any sweep jobs?',
#   'output': "You can give this house a once over. I hear they're fairly well-off and probably have lots of good stuff ripe for the picking. Sound good?"},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Do you have any sweep jobs?',
#   'output': 'The owner of this place just got an inheritance from a relative lost in the war. Sound like something you can sink your teeth into?'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "You're welcome to join me.",
#   'output': 'I thank you for your kindness. '},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Can I help you?',
#   'output': "I am a traveler. A pilgrim. I follow the voice of Kynareth wherever it can be heard.  I've dreamed of seeing Eldergleam for years. Might I travel alongside you? I promise not to get in the way."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "I'd rather not have company right now.",
#   'output': "I understand. Some journeys must be taken alone. I'll be here if you change your mind."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'What did you have in mind?',
#   'output': 'Follow me. I think I can convince the tree to help us. '},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Do you have a better idea?',
#   'output': "Well... yes. There is something.  It won't repair the tree back at the temple, but we could bring them a new one. "},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'I need sap to fix the Gildergreen.',
#   'output': "That's abominable. Barbaric. I'll have no part of this. Why didn't you tell me what you intended? You would violate this marvel of Kynareth's glory to fix that half-breed stump in Whiterun?"},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "What's wrong?",
#   'output': 'I had no idea you were a man of violence. What exactly are your intentions in this blessed place?'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Then stand aside. I have work to do.',
#   'output': 'With pleasure. Nature has a way of finding vengeance, though. You walk a bleak path, friend. One that will lead to suffering. '},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "I'll just take the sap. Danica was very insistent on having it.",
#   'output': "Very well. I can't stop you. But I can't bear to watch it, either. "},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'What sort of message?',
#   'output': "Ah, well, I recently approached Sibbi Black-Briar about buying Frost, one of the finest breeding horses in Skyrim. He agreed to sell. I paid Sibbi half the cost of Frost up front, but before he could deliver, Maven had him locked up. Sibbi believes this exempts him from our deal. I want you to talk to Sibbi for me. Then, I want you to bring me Frost and the Lineage Papers that prove the horse's worth. It does not."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "I'm not interested right now, thanks.",
#   'output': "That's a real shame. You would've fit the bill nicely."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Sounds easy enough.',
#   'output': "Good man. You won't regret it."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "Are you aware there's a plot to steal Frost?",
#   'output': "Don't tell me - Sibbi and Louis Letrush? Well, Sibbi is in jail and Letrush is certainly welcome to try. My hired help is more than a match for him."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Why is it so run down?',
#   'output': "Sad, isn't it? We can't afford to keep the place running since these attacks started. Pirates, you see. Raiding all along the coast, from Hammerfell to Vvardenfell. Only the Shatter-Shields appear safe."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'I know where the Blood Horkers are.',
#   'output': "Just in time. This is Adelaisa, one of my superiors from the Company. She's been dispatched to... eh... see to it that we get back on schedule. You should probably speak to her."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Have you heard of a pirate crew called the Blood Horkers?',
#   'output': "Heard of them? I've been captaining a crew for 'em well on nine years now. What's it to you?"},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'The pirate haven has been destroyed.',
#   'output': "I can't express how much easier you've made my job. Ah, yes, your pay. The Company thanks you for your services. Should we ever be able to help you, stop by. Maybe Adelaisa will finally ease up, but I expect she won't."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "I've got the logbook.",
#   'output': "How did you get it? No, never mind, I probably shouldn't know. I see... it looks like Suvaris has been traveling to Dawnstar to meet with a pirate crew there. Get to Dawnstar and see what you can find out about these rogues. I'd wager they won't be too far from the tavern. Try to find out where their fortress is. The captain, Stig Salt-Plank, has to know something."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'What would it take to identify the buyer? (Bribe)',
#   'output': "Well, now that you mention it, there is something I've been trying to get my hands on."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Get to the bottom of what?',
#   'output': "Whatever it is those Psijics are up to. They cannot be trusted. For all we know, he's here to scout out the College. I'm sure they want to undermine our efforts."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'What efforts would they be undermining?',
#   'output': "This! This... Orb. The Eye of Magnus, whatever you want to call it. It's clearly powerful, and no doubt they want it for themselves! I expect to be informed if they make any future attempts to contact you."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Sounds easy enough.',
#   'output': "Ah, you're a smart woman. That's exactly what I wanted to hear."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "So what's the plan?",
#   'output': "Head to the Riften jail and talk to Sibbi. Get him to tell you where Frost and his Lineage Papers are and bring them to me outside Riften. You'll be well paid for your time."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "What's the situation?",
#   'output': 'You ready, auxiliary?'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "I'm sorry boy, but I'm not who you think I am.",
#   'output': "Of course you are! I prayed, and you came, and now you'll accept my contract!"},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Contract?',
#   'output': "My mother, she... she died. I... I'm all alone now. So they sent me to that terrible orphanage in Riften. Honorhall. The headmistress is an evil, cruel woman. They call her Grelod the Kind. But she's not kind. She's terrible. To all of us. So I ran away, and came home. And performed the Black Sacrament. Now you're here! And you can kill Grelod the Kind!"},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': '(Remain silent)',
#   'output': "You don't have to say anything. There's no need. You're here, so I know you'll accept my contract."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Yes, of course... The Black Sacrament...',
#   'output': "It took so long. So very long. But now that you're here, you can accept my contract."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Are you all right?',
#   'output': "It worked! I knew you'd come, I just knew it!  I did the Black Sacrament, over and over. With the body, and the... the things. And then you came! An assassin from the Dark Brotherhood!"},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'That sounds pretty bad...',
#   'output': "You're damned right it does. I'll never breed another prize-winning goat like Gleda! And don't you think of coming back to Rorikstead until you get her back from that Giant."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'So all of this was just a prank?',
#   'output': 'Just a prank? Just a prank? The Daedric Lord of Debauchery does not deal in mere "pranks." This may have begun as a minor amusement, but it wasn\'t long before I realized you\'d make a more interesting bearer of my not-quite-holy staff.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
# ...
#   'input': "Yes, but there's a problem.",
#   'output': "A problem? Let me see it. This is just like Gallus. A dear friend, but always too clever for his own good. He's written all of the text in the Falmer language."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'What will it cost to change your mind? (Bribe)',
#   'output': "I'm not certain how many scholars you're accustomed to dealing with, but I can assure you that personal wealth is our lowest priority."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "You're making a mistake...",
#   'output': "There's no mistake. You're a wanted man... and it's time to pay for your crimes. There's no mistake. You're a wanted man... and it's time to pay for your crimes. There's no mistake. You're a wanted man... and it's time to pay for your crimes. There's no mistake. You're a wanted man... and it's time to pay for your crimes. There's no mistake. You're a wanted man... and it's time to pay for your crimes. There's no mistake. You're a wanted man... and it's time to pay for your crimes. There's no mistake. You're a wanted man... and it's time to pay for your crimes."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "I don't have time for this. Do you?",
#   'output': "Well, your bounty is low... All right, get out of my sight. But you're known to me now, scum. Remember that. Well, your bounty is low... All right, get out of my sight. But you're known to me now, scum. Remember that. Well, your bounty is low... All right, get out of my sight. But you're known to me now, scum. Remember that. Well, your bounty is low... All right, get out of my sight. But you're known to me now, scum. Remember that. Well, your bounty is low... All right, get out of my sight. But you're known to me now, scum. Remember that. Well, your bounty is low... All right, get out of my sight. But you're known to me now, scum. Remember that. Well, your bounty is low... All right, get out of my sight. But you're known to me now, scum. Remember that."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "I don't have time for this. Do you?",
#   'output': "You know what? You're not worth the hassle. Go... be some other guard's problem. You know what? You're not worth the hassle. Go... be some other guard's problem. You know what? You're not worth the hassle. Go... be some other guard's problem. You know what? You're not worth the hassle. Go... be some other guard's problem. You know what? You're not worth the hassle. Go... be some other guard's problem. You know what? You're not worth the hassle. Go... be some other guard's problem. You know what? You're not worth the hassle. Go... be some other guard's problem."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'I have the Horn of Jurgen Windcaller.',
#   'output': "Ah! You've retrieved the Horn of Jurgen Windcaller. Well done. You have now passed all the trials. Come with me. It is time for us to recognize you formally as Dragonborn."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Captain, Angela sent me to ask about her daughter.',
#   'output': 'Generally posting information is need to know only.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Who is Roggvir?',
#   'output': "He's the sorry bastard who's going to be executed. He's the sorry bastard who's going to be executed. He's the sorry bastard who's going to be executed. A gate guard who let Ulfric Stormcloak escape the city, after he killed the High King. A gate guard who let Ulfric Stormcloak escape the city, after he killed the High King. A gate guard who let Ulfric Stormcloak escape the city, after he killed the High King."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'How do I join the Imperial Legion?',
#   'output': "There's no greater honor than to serve. If you're serious about enlisting, speak to Legate Rikke in Castle Dour. There's no greater honor than to serve. If you're serious about enlisting, speak to Legate Rikke in Castle Dour. There's no greater honor than to serve. If you're serious about enlisting, speak to Legate Rikke in Castle Dour."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'I think Angela needs to know. (Persuade)',
#   'output': "I... I've been trying to find the time and place to let her know."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'I think Angela needs to know. (Persuade)',
#   'output': "I'm sorry, I can't help you."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "Tell me about her daughter. That's an order, Captain.",
#   'output': "Yes, Sir. Although I'm not sure you'll be happy to know."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "Fine. If that's the way you want it.",
#   'output': "That's the way it is."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Angela... Mrs. Morrard... your daughter is dead.',
#   'output': "I told her. I told her the imperial army would kill her. That this was a war of Jarls and Imperial Generals and we had no part in it. She just wouldn't hear it. It was brave of you to come to me with this. I can't thank you for it, not for this, but you have done me a service."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'I have some news about your daughter.',
#   'output': 'You got Aldis to tell you something? I knew you would. What did he say?'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Well, I\'m making it "need to know." (Intimidate)',
#   'output': 'If you want to know that bad then fine.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'DB07CiceroConfrontBranchTopic',
#   'output': 'You caught me! I surrender! Ha ha ha ha.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "I've heard you might know what Faleen likes.",
#   'output': 'What? Why, are you... interested?'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'What would inspire them to leave?',
#   'output': "Bassianus is still so terrified of Jofthor. If he knew that I'd keep him from hunting the poor boy down, he'd take Fastred to Riften without a second thought. Let him know that I'll watch out for them. I just want my daughter to be happy."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "Looks like there's not much you can do.",
#   'output': 'I guess not. '},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "Boti said she'd handle Jofthor.",
#   'output': "She would? If she's willing to deal with him, then everything would be all right. I'll... I'll go speak to Fastred. Post-haste!"},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'You just need to have something to talk about.',
#   'output': "That's the trouble. I know Faleen from the Keep, but I have no idea what sorts of things she likes. It's not a simple matter. I could offend her fairly easily by bringing up the wrong subject. I've seen it happen before."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "I'm not sure. I hope things work out for you.",
#   'output': "As do I. It's a puzzling situation."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'What do I have to do?',
#   'output': "Simple... I'm going to cause a distraction and you're going to steal Madesi's silver ring from a strongbox under his stand. Once you have it, I want you to place it in Brand-Shei's pocket without him noticing."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'My wealth is none of your business.',
#   'output': "Oh, but that's where you're wrong, lad. Wealth is my business. Maybe you'd like a taste?"},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'My wealth is none of your business.',
#   'output': "Oh, but that's where you're wrong, lass. Wealth is my business. Maybe you'd like a taste?"},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'What do you have in mind?',
#   'output': "I've got a bit of an errand to perform, but I need an extra pair of hands. And in my line of work, extra hands are well-paid."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "I'm sorry, what?",
#   'output': "I'm saying you've got the coin but you didn't earn a septim of it honestly. I can tell."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'How could you possibly know that?',
#   'output': "It's all about sizing up your mark, lad. The way they walk, what they're wearing. It's a dead giveaway."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'No, never mind.',
#   'output': "You're trying my patience, lad."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'No, never mind.',
#   'output': "You're trying my patience, lass."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Break the law? Are you kidding?',
#   'output': 'Sorry... I usually have a nose for this kind of thing. Never mind then, lad. If you change your mind, come find me.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'I can handle it.',
#   'output': "All right, then. Let's put that to the test. The group I represent has its home in the Ratway beneath Riften... a tavern called the Ragged Flagon. Get there in one piece and we'll see if you've really got what it takes."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "The money's nice, but I don't know...",
#   'output': "The group I represent has its home in the Ratway beneath Riften... a tavern called the Ragged Flagon. When you make up your mind, come find me there and we'll talk about your future. Look, I'll make this simple for you."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'No way. It was wrong to do those things.',
#   'output': "Arrogant, eh? Play it however you want, but listen up. The group I represent has its home in the Ratway beneath Riften... a tavern called the Ragged Flagon. When you come to your senses, find me there and we'll discuss your future."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "What's been going on?",
#   'output': "Bah. My organization's been having a run of bad luck, but I suppose that's just how it goes. But never mind that, you did the job and you did it well. Best of all, there's more where that came from... if you think you can handle it."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'What should we do?',
#   'output': 'Stay under cover. This is what we came for. We need to see what happens.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'What should we do?',
#   'output': "Steady. Let's see what it does."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Where are we headed?',
#   'output': "I don't know exactly. We need to find the ancient burial mound. Let's ask around town."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'My reasons are my own.',
#   'output': "A man's heart is his own burden to bear, so I will honor your request, though it casts a bit of gloom on an otherwise glorious day."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Maybe you should leave me out of your speech.',
#   'output': 'Oh, why is that?'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Consider it yours.',
#   'output': "That's great. I owe you one. Thanks!"},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Can I help you?',
#   'output': "Beg pardon. You dropped some armor over there. Don't suppose you'd mind if I... took it?"},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "It's mine. Don't touch it.",
#   'output': 'Oh. Well, you should probably go get it before someone steals it.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "Many have fought and died. I'm no different than they are.",
#   'output': 'On the contrary, you exceed the rest.  But, I will honor your request. The gods know of your victories, and they themselves will glory in your deeds.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Time to answer my questions.',
#   'output': "I owe you some answers, don't I?"},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'What should we do?',
#   'output': 'Kill the damn dragon! Unless you have a better idea?!'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Of course, my Lord.',
#   'output': 'Very good. Come, the people await us.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "I'm not sure this was all worth it, after all.",
#   'output': "There's no shame in such thoughts. A man without doubts is a man without a conscience.  But rest assured. We've won Skyrim's right to determine her own future. And for that, every Nord praises us.  But I will heed your wishes."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "I'll take that dog off your hands. (<global=animalgold> gold)",
#   'output': 'Sorry. You already have an animal with you.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "I'll take that dog off your hands. (<global=animalgold> gold)",
#   'output': 'War dogs cost gold, friend. Come back when you have some.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "It's mine. Don't touch it.",
#   'output': "Well... you probably should go collect it before someone else does, shouldn't you?"},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "It's mine. Don't touch it.",
#   'output': 'Oh... well. Never mind then.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "It's mine. Don't touch it.",
#   'output': "Well what did you go dropping it for? Got my hopes up for nothin'..."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "It's mine. Don't touch it.",
#   'output': "You dropped it by mistake? Well, if I was you, I'd go grab it now before somebody does. You dropped it by mistake? Well, if I was you, I'd go grab it now before somebody does."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "It's mine. Don't touch it.",
#   'output': 'Aww. I thought you were done with it.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "It's mine. Don't touch it.",
#   'output': "Well... fine. I wasn't really gonna do anything with it anyway. Hmph."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': "It's mine. Don't touch it.",
#   'output': "Well, you'd better go pick it up then, before someone snatches it."},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Sorry.',
#   'output': 'Stay away from my family if you value your life.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Sorry.',
#   'output': 'Good. But know that further dishonor to my family will mean your death.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Sorry.',
#   'output': 'You stay away from my family. Or you die. Be smart. Stay away.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Sorry.',
#   'output': 'This had better be the last I hear of you disrespecting my family.'},
#  {'instruction': 'Generate dialogue in the style of Skyrim.',
#   'input': 'Sorry.',
#   'output': 'Mark these words carefully, fetcher. Stay away from my family, or I will paint the ground with your blood.'},
#  ...]

# %%
with open('skyrim_alpaca_style_dataset.json', 'w') as json_file:
    json.dump(data, json_file, indent=4)
